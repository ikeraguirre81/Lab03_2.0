# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# # Default prediction for Lending Club data
#
# Authors : Iker Aguirre, Carlos Serrano
#
# Date : 04/12/2020

# %% [markdown]
# The purpose of this work is to create a model in order to predict if a future client of Lending Club will default or pay the full loan.
# We will follow the following steps:
#
# 1. Loading the data.
#
#
# 2. Preliminary exploratory analysis.
#
#
# 3. Transform the target variable.
#
#
# 4. Feature selection.
#
#
# 5. Drop highly correlated variables.
#
#
# 6. Apply the models
#
#
# 7. Compare the models.

# %%
data_raw1 = pd.read_csv('Loan_training_set_1_4.csv',
                      skiprows = 1)

# %% [markdown]
# # 1. Loading de Data

# %% [markdown]
# We currently have access to four different datasets, so we will load them and, using the pandas concat function, concatenate them into a single dataset.

# %%
data_raw1 = pd.read_csv('Loan_training_set_1_4.csv',
                      skiprows = 1)
data_raw2 = pd.read_csv('Loan_training_set_2_4.csv',
                      skiprows = 1)
data_raw3 = pd.read_csv('Loan_training_set_3_4.csv',
                      skiprows = 1)
data_raw4 = pd.read_csv('Loan_training_set_4_4.csv',
                      skiprows = 1)
# Out:
# /Users/ikeraguirreotaegui/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (0,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/ikeraguirreotaegui/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (0,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/ikeraguirreotaegui/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (0,19,129,130,131,134,135,136,139) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Users/ikeraguirreotaegui/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (0,19,59) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data = pd.concat([data_raw1, data_raw2, data_raw3, data_raw4])

# %% [markdown]
# # 2. Preliminary exploratory analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 884884 entries, 0 to 421096
# Columns: 151 entries, id to settlement_term
# dtypes: float64(111), object(40)
# memory usage: 1.0+ GB

# %%
data.head()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  112435993        NaN     2300.0       2300.0           2300.0   36 months
# 1  112290210        NaN    16000.0      16000.0          16000.0   60 months
# 2  112436985        NaN     6025.0       6025.0           6025.0   36 months
# 3  112439006        NaN    20400.0      20400.0          20400.0   36 months
# 4  112438929        NaN    13000.0      13000.0          13000.0   36 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0   12.62%        77.08     C        C1  ...                            NaN
# 1   12.62%       360.95     C        C1  ...                            NaN
# 2   15.05%       209.01     C        C4  ...                            NaN
# 3    9.44%       652.91     B        B1  ...                            NaN
# 4   11.99%       431.73     B        B5  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# 0                          NaN                Cash                     N
# 1                          NaN                Cash                     N
# 2                          NaN                Cash                     N
# 3                          NaN                Cash                     N
# 4                          NaN                Cash                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount settlement_percentage settlement_term
# 0               NaN                   NaN             NaN
# 1               NaN                   NaN             NaN
# 2               NaN                   NaN             NaN
# 3               NaN                   NaN             NaN
# 4               NaN                   NaN             NaN
#
# [5 rows x 151 columns]

# %%
data.describe()
# Out:
#        member_id      loan_amnt    funded_amnt  funded_amnt_inv  \
# count        0.0  884876.000000  884876.000000    884876.000000
# mean         NaN   14975.072016   14975.072016     14969.930469
# std          NaN    8804.519267    8804.519267      8801.522079
# min          NaN    1000.000000    1000.000000       900.000000
# 25%          NaN    8000.000000    8000.000000      8000.000000
# 50%          NaN   13000.000000   13000.000000     13000.000000
# 75%          NaN   20000.000000   20000.000000     20000.000000
# max          NaN   40000.000000   40000.000000     40000.000000
#
#          installment    annual_inc            dti    delinq_2yrs  \
# count  884876.000000  8.848760e+05  884615.000000  884876.000000
# mean      440.549628  7.710242e+04      18.903262       0.348848
# std       254.920865  1.354916e+05      11.722350       0.929979
# min        14.010000  0.000000e+00       0.000000       0.000000
# 25%       256.870000  4.600000e+04      12.330000       0.000000
# 50%       378.200000  6.500000e+04      18.220000       0.000000
# 75%       580.730000  9.200000e+04      24.770000       0.000000
# max      1719.830000  1.100000e+08     999.000000      42.000000
#
#        fico_range_low  fico_range_high  ...  deferral_term  hardship_amount  \
# count   884876.000000    884876.000000  ...         2661.0      2661.000000
# mean       694.698726       698.698854  ...            3.0       133.134930
# std         30.936483        30.937106  ...            0.0       113.474583
# min        660.000000       664.000000  ...            3.0         0.640000
# 25%        670.000000       674.000000  ...            3.0        46.410000
# 50%        685.000000       689.000000  ...            3.0       102.810000
# 75%        710.000000       714.000000  ...            3.0       187.880000
# max        845.000000       850.000000  ...            3.0       893.050000
#
#        hardship_length  hardship_dpd  \
# count           2661.0   2661.000000
# mean               3.0     11.635851
# std                0.0     10.335066
# min                3.0      0.000000
# 25%                3.0      0.000000
# 50%                3.0     12.000000
# 75%                3.0     21.000000
# max                3.0     32.000000
#
#        orig_projected_additional_accrued_interest  \
# count                                 2269.000000
# mean                                   396.396148
# std                                    339.570837
# min                                      1.920000
# 25%                                    139.170000
# 50%                                    304.740000
# 75%                                    558.870000
# max                                   2679.150000
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                     2661.000000                   2661.000000
# mean                     10337.284833                    184.650631
# std                       7206.873974                    191.519744
# min                         55.730000                      0.010000
# 25%                       4606.530000                     30.560000
# 50%                       8882.150000                    124.770000
# 75%                      14467.400000                    291.010000
# max                      40306.410000                   1247.480000
#
#        settlement_amount  settlement_percentage  settlement_term
# count        8520.000000            8520.000000      8520.000000
# mean         5252.542545              48.307514        10.570423
# std          3738.505953               8.882677         8.513096
# min            82.960000               0.550000         0.000000
# 25%          2367.000000              45.000000         1.000000
# 50%          4429.550000              45.175000        12.000000
# 75%          7176.242500              50.000000        18.000000
# max         30000.000000             521.350000        65.000000
#
# [8 rows x 111 columns]

# %%
list(data)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'verification_status_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_bc_dlq',
#  'mths_since_recent_inq',
#  'mths_since_recent_revol_delinq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'revol_bal_joint',
#  'sec_app_fico_range_low',
#  'sec_app_fico_range_high',
#  'sec_app_earliest_cr_line',
#  'sec_app_inq_last_6mths',
#  'sec_app_mort_acc',
#  'sec_app_open_acc',
#  'sec_app_revol_util',
#  'sec_app_open_act_il',
#  'sec_app_num_rev_accts',
#  'sec_app_chargeoff_within_12_mths',
#  'sec_app_collections_12_mths_ex_med',
#  'sec_app_mths_since_last_major_derog',
#  'hardship_flag',
#  'hardship_type',
#  'hardship_reason',
#  'hardship_status',
#  'deferral_term',
#  'hardship_amount',
#  'hardship_start_date',
#  'hardship_end_date',
#  'payment_plan_start_date',
#  'hardship_length',
#  'hardship_dpd',
#  'hardship_loan_status',
#  'orig_projected_additional_accrued_interest',
#  'hardship_payoff_balance_amount',
#  'hardship_last_payment_amount',
#  'disbursement_method',
#  'debt_settlement_flag',
#  'debt_settlement_flag_date',
#  'settlement_status',
#  'settlement_date',
#  'settlement_amount',
#  'settlement_percentage',
#  'settlement_term']

# %%
variables = pd.read_excel('LCDataDictionary.xlsx').dropna()
variables.style.set_properties(subset=['Description'], **{'width' :'850px'})
# Out:
# <style  type="text/css" >
#     #T_01b1a700_35fb_11eb_a33f_acde48001122row0_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row1_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row2_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row3_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row4_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row5_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row6_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row7_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row8_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row9_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row10_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row11_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row12_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row13_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row14_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row15_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row16_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row17_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row18_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row19_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row20_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row21_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row22_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row23_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row24_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row25_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row26_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row27_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row28_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row29_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row30_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row31_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row32_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row33_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row34_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row35_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row36_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row37_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row38_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row39_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row40_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row41_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row42_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row43_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row44_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row45_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row46_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row47_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row48_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row49_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row50_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row51_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row52_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row53_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row54_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row55_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row56_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row57_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row58_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row59_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row60_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row61_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row62_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row63_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row64_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row65_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row66_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row67_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row68_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row69_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row70_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row71_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row72_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row73_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row74_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row75_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row76_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row77_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row78_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row79_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row80_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row81_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row82_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row83_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row84_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row85_col1 {
#             width:  850px;
#         }    #T_01b1a700_35fb_11eb_a33f_acde48001122row86_col1 {
#             widt

# %% [markdown]
# # 3. Target variable

# %% [markdown]
# As we have said, the purpuse of this work is to be able to distinguish between potential defaults and clients that will pay the full loan without any short of late payment. First of all, we are going to explore the variable itself, and how many categories it is composed by.

# %%
data.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'In Grace Period', 'Late (31-120 days)',
#        'Late (16-30 days)', 'Charged Off', 'Default', nan], dtype=object)

# %% [markdown]
# There are 2 changes that need to be made in teh variable:
#
# 1. We are not interested in loans with the "Current" status, as we don't know if either they are going to be fully paid or if some late payments might occur.
#
# 2. Any late payment will be considered a default.
#
# From now on, all fully-paid loans will be represented with the value "1", whereas the rest will have a "0" on them.

# %%
def target_transformation(dataset):
    dataset = dataset[dataset.loan_status!= 'Current']
    dataset.loan_status.replace(['Fully Paid', 
                                 'In Grace Period', 
                                 'Late (31-120 days)',
                                 'Late (16-30 days)', 
                                 'Charged Off', 
                                 'Default'], 
                                 [1, 0, 0, 0, 0, 0], inplace = True)
    return dataset

# %%
data2 = target_transformation(data)
# Out:
# /Users/ikeraguirreotaegui/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
data2.loan_status.unique()
# Out:
# array([ 1.,  0., nan])

# %% [markdown]
# # 4. Feature selection.

# %% [markdown]
# We are going to select which variables should stay in the dataset.
#
# First of all, columns with more than a 35,5% of NaN values will be deleted

# %%
def na_filter(dataset):
    remove = set()
    na_total = dataset.isnull().sum()
    filas = len(dataset.index)
    z = filas * 0.355
    for i in na_total.index:
        if (na_total[i]>z):
            remove.add(i)
    for i in remove:
        dataset.drop(i, axis=1, inplace=True)
    return dataset

# %%
data3 = na_filter(data2)
# Out:
# /Users/ikeraguirreotaegui/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
data3
# Out:
#                                                       id  loan_amnt  \
# 8                                              112038251    11575.0
# 10                                             112149045     7200.0
# 24                                             112052261     7500.0
# 42                                             111999259    10000.0
# 91                                             111808508    14000.0
# ...                                                  ...        ...
# 421092                                          36271333    13000.0
# 421093                                          36490806    12000.0
# 421094                                          36271262    20000.0
# 421095  Total amount funded in policy code 1: 6417608175        NaN
# 421096  Total amount funded in policy code 2: 1944088810        NaN
#
#         funded_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 8           11575.0          11575.0   36 months    7.35%       359.26     A
# 10           7200.0           7200.0   36 months   24.85%       285.70     E
# 24           7500.0           7500.0   36 months    7.35%       232.79     A
# 42          10000.0          10000.0   60 months   16.02%       243.29     C
# 91          14000.0          14000.0   36 months   16.02%       492.34     C
# ...             ...              ...         ...      ...          ...   ...
# 421092      13000.0          13000.0   60 months   15.99%       316.07     D
# 421093      12000.0          12000.0   60 months   19.99%       317.86     E
# 421094      20000.0          20000.0   36 months   11.99%       664.20     B
# 421095          NaN              NaN         NaN      NaN          NaN   NaN
# 421096          NaN              NaN         NaN      NaN          NaN   NaN
#
#        sub_grade                        emp_title  ... percent_bc_gt_75  \
# 8             A4             Solutions Architect   ...             11.1
# 10            E3                              Pse  ...            100.0
# 24            A4               Associate Director  ...              8.3
# 42            C5                           Biller  ...              0.0
# 91            C5                       cdl driver  ...            100.0
# ...          ...                              ...  ...              ...
# 421092        D2         Radiologist Technologist  ...             50.0
# 421093        E3                          Painter  ...             66.7
# 421094        B5  Manager Hotel Operations Oasis   ...             50.0
# 421095       NaN                              NaN  ...              NaN
# 421096       NaN                              NaN  ...              NaN
#
#        pub_rec_bankruptcies  tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 8                       1.0        0.0        528172.0          100865.0
# 10                      0.0        0.0          7600.0            5588.0
# 24                      0.0        0.0        350617.0           45955.0
# 42                      2.0        0.0         34200.0           10956.0
# 91                      0.0        0.0        170591.0           27684.0
# ...                     ...        ...             ...               ...
# 421092                  1.0        0.0         51239.0           34178.0
# 421093                  0.0        0.0         96919.0           58418.0
# 421094                  0.0        1.0         43740.0           33307.0
# 421095                  NaN        NaN             NaN               NaN
# 421096                  NaN        NaN             NaN               NaN
#
#         total_bc_limit total_il_high_credit_limit hardship_flag  \
# 8              28100.0                   120572.0             N
# 10              3600.0                     4000.0             N
# 24             83700.0                    32239.0             N
# 42             18800.0                     5500.0             N
# 91              3000.0                    30321.0             N
# ...                ...                        ...           ...
# 421092         10600.0                    33239.0             N
# 421093          9700.0                    69919.0             N
# 421094         41700.0                        0.0             N
# 421095             NaN                        NaN           NaN
# 421096             NaN                        NaN           NaN
#
#        disbursement_method debt_settlement_flag
# 8                     Cash                    N
# 10                    Cash                    N
# 24                    Cash                    N
# 42                    Cash                    N
# 91                    Cash                    N
# ...                    ...                  ...
# 421092                Cash                    N
# 421093                Cash                    N
# 421094                Cash                    N
# 421095                 NaN                  NaN
# 421096                 NaN                  NaN
#
# [462199 rows x 93 columns]

# %% [markdown]
# As we can see, more than 50 variables have been removed from the dataset.
#
# Now, we are going to delete some variables with Business-knowledge crieria, this is, variables that we consider that have no impact whatsoever in the outcome of the payment of any loan, or that maybe they are explicitly included in other variables.

# %%
def bl_filter(dataset):  
    dataset.drop(['addr_state', 
                  'collection_recovery_fee', 
                  'collections_12_mths_ex_med',
                  'earliest_cr_line',
                  'emp_title',
                  'grade',
                  'id',
                  'issue_d',
                  'last_credit_pull_d',
                  'last_pymnt_d',
                  'num_tl_120dpd_2m',
                  'num_tl_30dpd',
                  'purpose',
                  'recoveries',
                  'sub_grade',
                  'term',
                  'url',
                  'zip_code',
                  'disbursement_method',
                  'emp_length',
                  'title'],
                 axis = 1,
                 inplace = True)
    return dataset

# %%
bl_filter(data3)
# Out:
# /Users/ikeraguirreotaegui/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         loan_amnt  funded_amnt  funded_amnt_inv int_rate  installment  \
# 8         11575.0      11575.0          11575.0    7.35%       359.26
# 10         7200.0       7200.0           7200.0   24.85%       285.70
# 24         7500.0       7500.0           7500.0    7.35%       232.79
# 42        10000.0      10000.0          10000.0   16.02%       243.29
# 91        14000.0      14000.0          14000.0   16.02%       492.34
# ...           ...          ...              ...      ...          ...
# 421092    13000.0      13000.0          13000.0   15.99%       316.07
# 421093    12000.0      12000.0          12000.0   19.99%       317.86
# 421094    20000.0      20000.0          20000.0   11.99%       664.20
# 421095        NaN          NaN              NaN      NaN          NaN
# 421096        NaN          NaN              NaN      NaN          NaN
#
#        home_ownership  annual_inc verification_status  loan_status pymnt_plan  \
# 8                 OWN    153000.0        Not Verified          1.0          n
# 10               RENT     50000.0     Source Verified          1.0          n
# 24           MORTGAGE    110000.0        Not Verified          1.0          n
# 42               RENT     51979.0     Source Verified          1.0          n
# 91           MORTGAGE     75000.0            Verified          1.0          n
# ...               ...         ...                 ...          ...        ...
# 421092           RENT     35000.0            Verified          0.0          n
# 421093           RENT     64400.0     Source Verified          0.0          n
# 421094           RENT    100000.0            Verified          1.0          n
# 421095            NaN         NaN                 NaN          NaN        NaN
# 421096            NaN         NaN                 NaN          NaN        NaN
#
#         ...  pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  \
# 8       ...            95.7              11.1                   1.0
# 10      ...            80.0             100.0                   0.0
# 24      ...           100.0               8.3                   0.0
# 42      ...           100.0               0.0                   2.0
# 91      ...            90.0             100.0                   0.0
# ...     ...             ...               ...                   ...
# 421092  ...           100.0              50.0                   1.0
# 421093  ...            95.0              66.7                   0.0
# 421094  ...           100.0              50.0                   0.0
# 421095  ...             NaN               NaN                   NaN
# 421096  ...             NaN               NaN                   NaN
#
#         tax_liens  tot_hi_cred_lim  total_bal_ex_mort  total_bc_limit  \
# 8             0.0         528172.0           100865.0         28100.0
# 10            0.0           7600.0             5588.0          3600.0
# 24            0.0         350617.0            45955.0         83700.0
# 42            0.0          34200.0            10956.0         18800.0
# 91            0.0         170591.0            27684.0          3000.0
# ...           ...              ...                ...             ...
# 421092        0.0          51239.0            34178.0         10600.0
# 421093        0.0          96919.0            58418.0          9700.0
# 421094        1.0          43740.0            33307.0         41700.0
# 421095        NaN              NaN                NaN             NaN
# 421096        NaN              NaN                NaN             NaN
#
#         total_il_high_credit_limit hardship_flag  debt_settlement_flag
# 8                         120572.0             N                     N
# 10                          4000.0             N                     N
# 24                         32239.0             N                     N
# 42                          5500.0             N                     N
# 91                         30321.0             N                     N
# ...                            ...           ...                   ...
# 421092                     33239.0             N                     N
# 421093                     69919.0             N                     N
# 421094                         0.0             N                     N
# 421095                         NaN           NaN                   NaN
# 421096                         NaN           NaN                   NaN
#
# [462199 rows x 72 columns]

# %% [markdown]
# Lastly, we decided to drop all observations with NaN values on them, as we consider that substituing them with other statistical measurments (mean, median, etc) might not be ideal for this type of dataset.

# %%
data3.isna().sum()
# Out:
# loan_amnt                     8
# funded_amnt                   8
# funded_amnt_inv               8
# int_rate                      8
# installment                   8
#                              ..
# total_bal_ex_mort             8
# total_bc_limit                8
# total_il_high_credit_limit    8
# hardship_flag                 8
# debt_settlement_flag          8
# Length: 72, dtype: int64

# %%
data3.shape
# Out:
# (462199, 72)

# %%
data4 = data3.dropna()

# %%
data4.shape
# Out:
# (406075, 72)

# %% [markdown]
# # 4. Encoding

# %% [markdown]
# There are some categorical variables that we are going to transform into numeric.

# %%
types = data4.dtypes
types_2 = pd.DataFrame(types)

# %%
objects = types_2[types_2[0]=='object']
objects
# Out:
#                            0
# int_rate              object
# home_ownership        object
# verification_status   object
# pymnt_plan            object
# revol_util            object
# initial_list_status   object
# application_type      object
# hardship_flag         object
# debt_settlement_flag  object

# %%
data4.int_rate.unique()
# Out:
# array(['  7.35%', ' 24.85%', ' 16.02%', ' 30.79%', ' 20.00%', ' 11.99%',
#        ' 18.06%', ' 10.91%', ' 10.42%', '  9.44%', ' 15.05%', ' 21.45%',
#        '  9.93%', ' 30.65%', ' 13.59%', ' 23.88%', '  5.32%', ' 25.82%',
#        ' 14.08%', ' 19.03%', ' 26.30%', ' 17.09%', ' 30.17%', '  7.21%',
#        ' 12.62%', '  7.97%', ' 30.75%', '  7.07%', ' 30.84%', ' 29.69%',
#        ' 30.94%', ' 22.91%', ' 30.89%', ' 30.99%', ' 28.72%', ' 13.49%',
#        ' 12.74%', ' 15.99%', ' 14.99%', ' 11.44%', ' 24.74%', ' 28.69%',
#        '  7.49%', ' 29.99%', ' 13.99%', ' 10.49%', ' 19.99%', ' 18.99%',
#        '  8.24%', ' 11.49%', ' 17.99%', ' 16.99%', ' 26.24%', ' 30.49%',
#        ' 23.99%', ' 25.49%', ' 11.39%', ' 21.49%', ' 22.74%', '  7.99%',
#        '  6.99%', ' 30.74%', '  7.24%', ' 29.49%', '  6.00%', ' 15.59%',
#        ' 13.66%', ' 14.31%', ' 17.86%', ' 12.39%', ' 12.99%', '  9.49%',
#        '  8.67%', '  8.19%', ' 16.49%', ' 21.99%', ' 22.99%', ' 17.14%',
#        ' 19.24%', ' 18.54%', ' 25.83%', ' 25.80%', ' 24.50%', '  6.49%',
#        ' 25.89%', '  6.03%', ' 20.99%', ' 24.99%', ' 25.99%', ' 25.57%',
#        ' 26.06%', ' 17.57%', ' 14.49%', ' 12.49%', ' 16.29%', ' 10.15%',
#        '  8.39%', ' 23.43%', ' 15.61%', ' 13.98%', ' 18.24%', '  9.17%',
#        '  7.69%', ' 10.99%', ' 19.52%', ' 11.67%', ' 13.35%', ' 22.15%',
#        '  7.12%', ' 20.20%', ' 24.08%', ' 21.18%', ' 13.65%', '  9.67%',
#        '  8.90%', ' 15.31%', ' 14.64%', ' 18.25%', ' 14.16%', ' 19.47%',
#        '  7.90%', '  7.62%', ' 16.59%', ' 20.49%', '  6.62%', ' 18.92%',
#        ' 22.45%', ' 23.70%', ' 12.85%', ' 14.47%', ' 19.97%', ' 19.22%',
#        ' 13.53%', ' 21.48%', ' 16.24%', ' 20.50%', ' 23.40%', ' 14.98%',
#        ' 22.90%', ' 22.40%', ' 19.20%', '  9.80%', ' 15.77%', ' 10.78%',
#        ' 17.27%', ' 14.85%', ' 12.88%', ' 19.48%', ' 18.49%', ' 11.48%',
#        ' 13.44%', ' 19.89%', '  8.49%', ' 17.97%', ' 24.24%', ' 23.13%',
#        '  7.91%', ' 27.49%', ' 27.99%', ' 28.49%', ' 25.09%', ' 28.99%',
#        ' 26.99%', ' 13.67%', ' 16.55%', ' 10.64%', ' 13.18%', '  7.26%',
#        ' 15.41%', ' 14.48%', '  8.38%', ' 12.59%', ' 11.22%', '  9.76%',
#        '  6.89%', '  7.89%', ' 18.20%', ' 27.88%', '  6.24%', ' 27.31%',
#        ' 26.77%', ' 12.05%', '  9.99%', ' 14.33%', '  8.18%', ' 16.90%',
#        ' 18.55%', ' 12.69%', ' 13.33%', ' 11.53%', ' 12.29%', ' 14.65%',
#        ' 19.19%', ' 25.78%', '  5.93%', '  6.68%', ' 21.67%', '  6.39%',
#        '  6.92%', ' 18.84%'], dtype=object)

# %%
data4.home_ownership.unique()
# Out:
# array(['OWN', 'RENT', 'MORTGAGE', 'ANY'], dtype=object)

# %%
data4.verification_status.unique()
# Out:
# array(['Not Verified', 'Source Verified', 'Verified'], dtype=object)

# %%
data4.pymnt_plan.unique()
# Out:
# array(['n', 'y'], dtype=object)

# %%
data4.revol_util.unique()
# Out:
# array(['22.7%', '98.9%', '27.2%', ..., '123.3%', '121.4%', '106.8%'],
#       dtype=object)

# %%
data4.initial_list_status.unique()
# Out:
# array(['w', 'f'], dtype=object)

# %%
data4.application_type.unique()
# Out:
# array(['Individual', 'Joint App'], dtype=object)

# %%
data4.hardship_flag.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
data4.debt_settlement_flag.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %% [markdown]
# Two changes need to be made in this dataset:
#
# 1. "int_rate" and "revol_util" will be converted into numeric, with no porcentages
#
# 2. The rest of variables will get dummied, as we consider that their categories are very well defined and any of them exceed 5 or more categories

# %%
data4['int_rate'] = data4['int_rate'].str.rstrip('%').astype('float') / 100.0
# Out:
# <ipython-input-38-278ec4f35b47>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4['int_rate'] = data4['int_rate'].str.rstrip('%').astype('float') / 100.0

# %%
data4.int_rate.unique()
# Out:
# array([0.0735, 0.2485, 0.1602, 0.3079, 0.2   , 0.1199, 0.1806, 0.1091,
#        0.1042, 0.0944, 0.1505, 0.2145, 0.0993, 0.3065, 0.1359, 0.2388,
#        0.0532, 0.2582, 0.1408, 0.1903, 0.263 , 0.1709, 0.3017, 0.0721,
#        0.1262, 0.0797, 0.3075, 0.0707, 0.3084, 0.2969, 0.3094, 0.2291,
#        0.3089, 0.3099, 0.2872, 0.1349, 0.1274, 0.1599, 0.1499, 0.1144,
#        0.2474, 0.2869, 0.0749, 0.2999, 0.1399, 0.1049, 0.1999, 0.1899,
#        0.0824, 0.1149, 0.1799, 0.1699, 0.2624, 0.3049, 0.2399, 0.2549,
#        0.1139, 0.2149, 0.2274, 0.0799, 0.0699, 0.3074, 0.0724, 0.2949,
#        0.06  , 0.1559, 0.1366, 0.1431, 0.1786, 0.1239, 0.1299, 0.0949,
#        0.0867, 0.0819, 0.1649, 0.2199, 0.2299, 0.1714, 0.1924, 0.1854,
#        0.2583, 0.258 , 0.245 , 0.0649, 0.2589, 0.0603, 0.2099, 0.2499,
#        0.2599, 0.2557, 0.2606, 0.1757, 0.1449, 0.1249, 0.1629, 0.1015,
#        0.0839, 0.2343, 0.1561, 0.1398, 0.1824, 0.0917, 0.0769, 0.1099,
#        0.1952, 0.1167, 0.1335, 0.2215, 0.0712, 0.202 , 0.2408, 0.2118,
#        0.1365, 0.0967, 0.089 , 0.1531, 0.1464, 0.1825, 0.1416, 0.1947,
#        0.079 , 0.0762, 0.1659, 0.2049, 0.0662, 0.1892, 0.2245, 0.237 ,
#        0.1285, 0.1447, 0.1997, 0.1922, 0.1353, 0.2148, 0.1624, 0.205 ,
#        0.234 , 0.1498, 0.229 , 0.224 , 0.192 , 0.098 , 0.1577, 0.1078,
#        0.1727, 0.1485, 0.1288, 0.1948, 0.1849, 0.1148, 0.1344, 0.1989,
#        0.0849, 0.1797, 0.2424, 0.2313, 0.0791, 0.2749, 0.2799, 0.2849,
#        0.2509, 0.2899, 0.2699, 0.1367, 0.1655, 0.1064, 0.1318, 0.0726,
#        0.1541, 0.1448, 0.0838, 0.1259, 0.1122, 0.0976, 0.0689, 0.0789,
#        0.182 , 0.2788, 0.0624, 0.2731, 0.2677, 0.1205, 0.0999, 0.1433,
#        0.0818, 0.169 , 0.1855, 0.1269, 0.1333, 0.1153, 0.1229, 0.1465,
#        0.1919, 0.2578, 0.0593, 0.0668, 0.2167, 0.0639, 0.0692, 0.1884])

# %%
data4['revol_util'] = data4['revol_util'].str.rstrip('%').astype('float') / 100.0
# Out:
# <ipython-input-40-0b227b6ba605>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4['revol_util'] = data4['revol_util'].str.rstrip('%').astype('float') / 100.0

# %%
data4.revol_util.unique()
# Out:
# array([0.227, 0.989, 0.272, ..., 1.233, 1.214, 1.068])

# %%
data5 = pd.get_dummies(data4,
                       columns = ['home_ownership',
                                  'verification_status',
                                  'pymnt_plan',
                                  'initial_list_status',
                                  'application_type',
                                  'hardship_flag',
                                  'debt_settlement_flag'],
                       drop_first = True)
data5
# Out:
#         loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  \
# 8         11575.0      11575.0          11575.0    0.0735       359.26
# 10         7200.0       7200.0           7200.0    0.2485       285.70
# 24         7500.0       7500.0           7500.0    0.0735       232.79
# 42        10000.0      10000.0          10000.0    0.1602       243.29
# 91        14000.0      14000.0          14000.0    0.1602       492.34
# ...           ...          ...              ...       ...          ...
# 421088    11575.0      11575.0          11575.0    0.1559       404.61
# 421089    12000.0      12000.0          12000.0    0.1199       398.52
# 421092    13000.0      13000.0          13000.0    0.1599       316.07
# 421093    12000.0      12000.0          12000.0    0.1999       317.86
# 421094    20000.0      20000.0          20000.0    0.1199       664.20
#
#         annual_inc  loan_status    dti  delinq_2yrs  fico_range_low  ...  \
# 8         153000.0          1.0  16.99          0.0           720.0  ...
# 10         50000.0          1.0   6.07          0.0           685.0  ...
# 24        110000.0          1.0  13.12          0.0           710.0  ...
# 42         51979.0          1.0  10.11          0.0           690.0  ...
# 91         75000.0          1.0  10.86          1.0           685.0  ...
# ...            ...          ...    ...          ...             ...  ...
# 421088     25400.0          1.0  27.08          0.0           680.0  ...
# 421089     63000.0          0.0  23.69          1.0           685.0  ...
# 421092     35000.0          0.0  30.90          0.0           680.0  ...
# 421093     64400.0          0.0  27.19          1.0           695.0  ...
# 421094    100000.0          1.0  10.83          0.0           675.0  ...
#
#         home_ownership_MORTGAGE  home_ownership_OWN  home_ownership_RENT  \
# 8                             0                   1                    0
# 10                            0                   0                    1
# 24                            1                   0                    0
# 42                            0                   0                    1
# 91                            1                   0                    0
# ...                         ...                 ...                  ...
# 421088                        0                   0                    1
# 421089                        1                   0                    0
# 421092                        0                   0                    1
# 421093                        0                   0                    1
# 421094                        0                   0                    1
#
#         verification_status_Source Verified  verification_status_Verified  \
# 8                                         0                             0
# 10                                        1                             0
# 24                                        0                             0
# 42                                        1                             0
# 91                                        0                             1
# ...                                     ...                           ...
# 421088                                    0                             1
# 421089                                    0                             1
# 421092                                    0                             1
# 421093                                    1                             0
# 421094                                    0                             1
#
#         pymnt_plan_y  initial_list_status_w  application_type_Joint App  \
# 8                  0                      1                           0
# 10                 0                      1                           0
# 24                 0                      1                           0
# 42                 0                      1                           0
# 91                 0                      1                           0
# ...              ...                    ...                         ...
# 421088             0                      0                           0
# 421089             0                      0                           0
# 421092             0                      1                           0
# 421093             0                      1                           0
# 421094             0                      0                           0
#
#         hardship_flag_Y  debt_settlement_flag_Y
# 8                     0                       0
# 10                    0                       0
# 24                    0                       0
# 42                    0                       0
# 91                    0                       0
# ...                 ...                     ...
# 421088                0                       0
# 421089                0                       0
# 421092                0                       0
# 421093                0                       0
# 421094                0                       0
#
# [406075 rows x 75 columns]

# %% [markdown]
# # 5. Highly correlated features.

# %%
data5.corr()
# Out:
#                             loan_amnt  funded_amnt  funded_amnt_inv  int_rate  \
# loan_amnt                    1.000000     1.000000         0.999995  0.141352
# funded_amnt                  1.000000     1.000000         0.999995  0.141352
# funded_amnt_inv              0.999995     0.999995         1.000000  0.141236
# int_rate                     0.141352     0.141352         0.141236  1.000000
# installment                  0.951008     0.951008         0.950991  0.132658
# ...                               ...          ...              ...       ...
# pymnt_plan_y                 0.008716     0.008716         0.008721  0.010324
# initial_list_status_w        0.055643     0.055643         0.056230 -0.094270
# application_type_Joint App   0.034144     0.034144         0.034142  0.037932
# hardship_flag_Y              0.010797     0.010797         0.010801  0.013264
# debt_settlement_flag_Y       0.010942     0.010942         0.010906  0.047594
#
#                             installment  annual_inc  loan_status       dti  \
# loan_amnt                      0.951008    0.329747    -0.067476  0.009633
# funded_amnt                    0.951008    0.329747    -0.067476  0.009633
# funded_amnt_inv                0.950991    0.329794    -0.067401  0.009537
# int_rate                       0.132658   -0.083467    -0.268433  0.171644
# installment                    1.000000    0.323015    -0.040643  0.005082
# ...                                 ...         ...          ...       ...
# pymnt_plan_y                   0.007450   -0.001118    -0.049718  0.008510
# initial_list_status_w         -0.000225    0.027221    -0.004413 -0.012074
# application_type_Joint App     0.034682   -0.018760    -0.025248  0.098371
# hardship_flag_Y                0.008841   -0.000464    -0.058117  0.008623
# debt_settlement_flag_Y         0.005853   -0.010771    -0.235445  0.042057
#
#                             delinq_2yrs  fico_range_low  ...  \
# loan_amnt                     -0.007918        0.136715  ...
# funded_amnt                   -0.007918        0.136715  ...
# funded_amnt_inv               -0.007941        0.136836  ...
# int_rate                       0.049004       -0.379633  ...
# installment                    0.002242        0.094341  ...
# ...                                 ...             ...  ...
# pymnt_plan_y                   0.005237       -0.008288  ...
# initial_list_status_w         -0.011484        0.080679  ...
# application_type_Joint App     0.001327        0.011085  ...
# hardship_flag_Y                0.005249       -0.010348  ...
# debt_settlement_flag_Y         0.002771       -0.024854  ...
#
#                             home_ownership_MORTGAGE  home_ownership_OWN  \
# loan_amnt                                  0.180910           -0.016889
# funded_amnt                                0.180910           -0.016889
# funded_amnt_inv                            0.180936           -0.016898
# int_rate                                  -0.064081            0.010768
# installment                                0.153498           -0.012706
# ...                                             ...                 ...
# pymnt_plan_y                              -0.004311            0.002987
# initial_list_status_w                      0.031834           -0.000849
# application_type_Joint App                 0.019896           -0.002535
# hardship_flag_Y                           -0.004409            0.001144
# debt_settlement_flag_Y                    -0.018477            0.005026
#
#                             home_ownership_RENT  \
# loan_amnt                             -0.175212
# funded_amnt                           -0.175212
# funded_amnt_inv                       -0.175233
# int_rate                               0.059095
# installment                           -0.149668
# ...                                         ...
# pymnt_plan_y                           0.002572
# initial_list_status_w                 -0.032149
# application_type_Joint App            -0.018849
# hardship_flag_Y                        0.003816
# debt_settlement_flag_Y                 0.015848
#
#                             verification_status_Source Verified  \
# loan_amnt                                              0.071540
# funded_amnt                                            0.071540
# funded_amnt_inv                                        0.071551
# int_rate                                               0.019821
# installment                                            0.052974
# ...                                                         ...
# pymnt_plan_y                                           0.000466
# initial_list_status_w                                  0.021491
# application_type_Joint App                            -0.011855
# hardship_flag_Y                                        0.001013
# debt_settlement_flag_Y                                 0.002893
#
#                             verification_status_Verified  pymnt_plan_y  \
# loan_amnt                                       0.183738      0.008716
# funded_amnt                                     0.183738      0.008716
# funded_amnt_inv                                 0.183683      0.008721
# int_rate                                        0.201794      0.010324
# installment                                     0.196255      0.007450
# ...                                                  ...           ...
# pymnt_plan_y                                    0.004742      1.000000
# initial_list_status_w                          -0.031122      0.004540
# application_type_Joint App                      0.015884      0.001107
# hardship_flag_Y                                 0.005883      0.855476
# debt_settlement_flag_Y                          0.019118     -0.004050
#
#                             initial_list_status_w  application_type_Joint App  \
# loan_amnt                                0.055643                    0.034144
# funded_amnt                              0.055643                    0.034144
# funded_amnt_inv                          0.056230                    0.034142
# int_rate                                -0.094270                    0.037932
# installment                             -0.000225                    0.034682
# ...                                           ...                         ...
# pymnt_plan_y                             0.004540                    0.001107
# initial_list_status_w                    1.000000                    0.022146
# application_type_Joint App               0.022146                    1.000000
# hardship_flag_Y                          0.004927                    0.000403
# debt_settlement_flag_Y                  -0.010423                   -0.007009
#
#                             hardship_flag_Y  debt_settlement_flag_Y
# loan_amnt                          0.010797                0.010942
# funded_amnt                        0.010797                0.010942
# funded_amnt_inv                    0.010801                0.010906
# int_rate                           0.013264                0.047594
# installment                        0.008841                0.005853
# ...                                     ...                     ...
# pymnt_plan_y                       0.855476               -0.004050
# initial_list_status_w              0.004927               -0.010423
# application_type_Joint App         0.000403               -0.007009
# hardship_flag_Y                    1.000000               -0.004734
# debt_settlement_flag_Y            -0.004734                1.000000
#
# [75 rows x 75 columns]

# %% [markdown]
# We are dropping highly correlated features, this is, independent variables with high correlations between them:
#
# 1. (0.8 to 1)
#
# 2. (-0.8 to -1)

# %%
def correlation(dataset, threshold):
    corr_columns = set()  
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: 
                colname = corr_matrix.columns[i]  
                corr_columns.add(colname)
    return corr_columns

# %%
corr_data = correlation(data5, 0.8)
corr_data
# Out:
# {'avg_cur_bal',
#  'bc_util',
#  'fico_range_high',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'hardship_flag_Y',
#  'home_ownership_RENT',
#  'installment',
#  'last_fico_range_low',
#  'num_bc_sats',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'out_prncp_inv',
#  'percent_bc_gt_75',
#  'tot_hi_cred_lim',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rev_hi_lim'}

# %%
data6 = data5.drop(corr_data, axis = 1)
data6
# Out:
#         loan_amnt  int_rate  annual_inc  loan_status    dti  delinq_2yrs  \
# 8         11575.0    0.0735    153000.0          1.0  16.99          0.0
# 10         7200.0    0.2485     50000.0          1.0   6.07          0.0
# 24         7500.0    0.0735    110000.0          1.0  13.12          0.0
# 42        10000.0    0.1602     51979.0          1.0  10.11          0.0
# 91        14000.0    0.1602     75000.0          1.0  10.86          1.0
# ...           ...       ...         ...          ...    ...          ...
# 421088    11575.0    0.1559     25400.0          1.0  27.08          0.0
# 421089    12000.0    0.1199     63000.0          0.0  23.69          1.0
# 421092    13000.0    0.1599     35000.0          0.0  30.90          0.0
# 421093    12000.0    0.1999     64400.0          0.0  27.19          1.0
# 421094    20000.0    0.1199    100000.0          1.0  10.83          0.0
#
#         fico_range_low  inq_last_6mths  open_acc  pub_rec  ...  tax_liens  \
# 8                720.0             0.0      20.0      1.0  ...        0.0
# 10               685.0             0.0       4.0      0.0  ...        0.0
# 24               710.0             2.0      19.0      0.0  ...        0.0
# 42               690.0             0.0      15.0      2.0  ...        0.0
# 91               685.0             0.0       4.0      0.0  ...        0.0
# ...                ...             ...       ...      ...  ...        ...
# 421088           680.0             0.0       9.0      0.0  ...        0.0
# 421089           685.0             0.0      13.0      0.0  ...        0.0
# 421092           680.0             0.0       9.0      1.0  ...        0.0
# 421093           695.0             2.0      17.0      0.0  ...        0.0
# 421094           675.0             1.0       8.0      1.0  ...        1.0
#
#         total_bal_ex_mort  home_ownership_MORTGAGE  home_ownership_OWN  \
# 8                100865.0                        0                   1
# 10                 5588.0                        0                   0
# 24                45955.0                        1                   0
# 42                10956.0                        0                   0
# 91                27684.0                        1                   0
# ...                   ...                      ...                 ...
# 421088            19798.0                        0                   0
# 421089           112990.0                        1                   0
# 421092            34178.0                        0                   0
# 421093            58418.0                        0                   0
# 421094            33307.0                        0                   0
#
#         verification_status_Source Verified  verification_status_Verified  \
# 8                                         0                             0
# 10                                        1                             0
# 24                                        0                             0
# 42                                        1                             0
# 91                                        0                             1
# ...                                     ...                           ...
# 421088                                    0                             1
# 421089                                    0                             1
# 421092                                    0                             1
# 421093                                    1                             0
# 421094                                    0                             1
#
#         pymnt_plan_y  initial_list_status_w  application_type_Joint App  \
# 8                  0                      1                           0
# 10                 0                      1                           0
# 24                 0                      1                           0
# 42                 0                      1                           0
# 91                 0                      1                           0
# ...              ...                    ...                         ...
# 421088             0                      0                           0
# 421089             0                      0                           0
# 421092             0                      1                           0
# 421093             0                      1                           0
# 421094             0                      0                           0
#
#         debt_settlement_flag_Y
# 8                            0
# 10                           0
# 24                           0
# 42                           0
# 91                           0
# ...                        ...
# 421088                       0
# 421089                       0
# 421092                       0
# 421093                       0
# 421094                       0
#
# [406075 rows x 52 columns]

# %%
corr1 = data6[data6.columns[0:16]].corr()

# %%
corr2 = data6[data6.columns[17:32]].corr()

# %%
corr3 = data6[data6.columns[33:52]].corr()

# %%
sns.heatmap(corr1, cmap = 'coolwarm')

# %%
sns.heatmap(corr2, cmap = 'coolwarm')

# %%
sns.heatmap(corr3, cmap = 'coolwarm')

# %% [markdown]
# # 6. Cleaned-data exploratory analysis

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406075 entries, 8 to 421094
# Data columns (total 52 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   loan_amnt                            406075 non-null  float64
#  1   int_rate                             406075 non-null  float64
#  2   annual_inc                           406075 non-null  float64
#  3   loan_status                          406075 non-null  float64
#  4   dti                                  406075 non-null  float64
#  5   delinq_2yrs                          406075 non-null  float64
#  6   fico_range_low                       406075 non-null  float64
#  7   inq_last_6mths                       406075 non-null  float64
#  8   open_acc                             406075 non-null  float64
#  9   pub_rec                              406075 non-null  float64
#  10  revol_bal                            406075 non-null  float64
#  11  revol_util                           406075 non-null  float64
#  12  total_acc                            406075 non-null  float64
#  13  out_prncp                            406075 non-null  float64
#  14  total_rec_int                        406075 non-null  float64
#  15  total_rec_late_fee                   406075 non-null  float64
#  16  last_pymnt_amnt                      406075 non-null  float64
#  17  last_fico_range_high                 406075 non-null  float64
#  18  policy_code                          406075 non-null  float64
#  19  acc_now_delinq                       406075 non-null  float64
#  20  tot_coll_amt                         406075 non-null  float64
#  21  tot_cur_bal                          406075 non-null  float64
#  22  acc_open_past_24mths                 406075 non-null  float64
#  23  bc_open_to_buy                       406075 non-null  float64
#  24  chargeoff_within_12_mths             406075 non-null  float64
#  25  delinq_amnt                          406075 non-null  float64
#  26  mo_sin_old_il_acct                   406075 non-null  float64
#  27  mo_sin_old_rev_tl_op                 406075 non-null  float64
#  28  mo_sin_rcnt_rev_tl_op                406075 non-null  float64
#  29  mo_sin_rcnt_tl                       406075 non-null  float64
#  30  mort_acc                             406075 non-null  float64
#  31  mths_since_recent_bc                 406075 non-null  float64
#  32  mths_since_recent_inq                406075 non-null  float64
#  33  num_accts_ever_120_pd                406075 non-null  float64
#  34  num_actv_bc_tl                       406075 non-null  float64
#  35  num_actv_rev_tl                      406075 non-null  float64
#  36  num_bc_tl                            406075 non-null  float64
#  37  num_il_tl                            406075 non-null  float64
#  38  num_tl_90g_dpd_24m                   406075 non-null  float64
#  39  num_tl_op_past_12m                   406075 non-null  float64
#  40  pct_tl_nvr_dlq                       406075 non-null  float64
#  41  pub_rec_bankruptcies                 406075 non-null  float64
#  42  tax_liens                            406075 non-null  float64
#  43  total_bal_ex_mort                    406075 non-null  float64
#  44  home_ownership_MORTGAGE              406075 non-null  uint8
#  45  home_ownership_OWN                   406075 non-null  uint8
#  46  verification_status_Source Verified  406075 non-null  uint8
#  47  verification_status_Verified         406075 non-null  uint8
#  48  pymnt_plan_y                         406075 non-null  uint8
#  49  initial_list_status_w                406075 non-null  uint8
#  50  application_type_Joint App           406075 non-null  uint8
#  51  debt_settlement_flag_Y               406075 non-null  uint8
# dtypes: float64(44), uint8(8)
# memory usage: 152.5 MB

# %%
data6.head()
# Out:
#     loan_amnt  int_rate  annual_inc  loan_status    dti  delinq_2yrs  \
# 8     11575.0    0.0735    153000.0          1.0  16.99          0.0
# 10     7200.0    0.2485     50000.0          1.0   6.07          0.0
# 24     7500.0    0.0735    110000.0          1.0  13.12          0.0
# 42    10000.0    0.1602     51979.0          1.0  10.11          0.0
# 91    14000.0    0.1602     75000.0          1.0  10.86          1.0
#
#     fico_range_low  inq_last_6mths  open_acc  pub_rec  ...  tax_liens  \
# 8            720.0             0.0      20.0      1.0  ...        0.0
# 10           685.0             0.0       4.0      0.0  ...        0.0
# 24           710.0             2.0      19.0      0.0  ...        0.0
# 42           690.0             0.0      15.0      2.0  ...        0.0
# 91           685.0             0.0       4.0      0.0  ...        0.0
#
#     total_bal_ex_mort  home_ownership_MORTGAGE  home_ownership_OWN  \
# 8            100865.0                        0                   1
# 10             5588.0                        0                   0
# 24            45955.0                        1                   0
# 42            10956.0                        0                   0
# 91            27684.0                        1                   0
#
#     verification_status_Source Verified  verification_status_Verified  \
# 8                                     0                             0
# 10                                    1                             0
# 24                                    0                             0
# 42                                    1                             0
# 91                                    0                             1
#
#     pymnt_plan_y  initial_list_status_w  application_type_Joint App  \
# 8              0                      1                           0
# 10             0                      1                           0
# 24             0                      1                           0
# 42             0                      1                           0
# 91             0                      1                           0
#
#     debt_settlement_flag_Y
# 8                        0
# 10                       0
# 24                       0
# 42                       0
# 91                       0
#
# [5 rows x 52 columns]

# %%
data6.describe()
# Out:
#            loan_amnt       int_rate    annual_inc    loan_status  \
# count  406075.000000  406075.000000  4.060750e+05  406075.000000
# mean    14766.353691       0.134604  7.697423e+04       0.742944
# std      8547.214412       0.045223  6.687852e+04       0.437011
# min      1000.000000       0.053200  6.000000e+02       0.000000
# 25%      8000.000000       0.099900  4.730000e+04       0.000000
# 50%     12950.000000       0.131800  6.500000e+04       1.000000
# 75%     20000.000000       0.162900  9.200000e+04       1.000000
# max     40000.000000       0.309900  9.500000e+06       1.000000
#
#                  dti    delinq_2yrs  fico_range_low  inq_last_6mths  \
# count  406075.000000  406075.000000   406075.000000   406075.000000
# mean       18.790558       0.347960      692.143286        0.769173
# std         8.638254       0.921531       29.628271        1.003296
# min         0.000000       0.000000      660.000000        0.000000
# 25%        12.560000       0.000000      670.000000        0.000000
# 50%        18.280000       0.000000      685.000000        0.000000
# 75%        24.640000       0.000000      705.000000        1.000000
# max       999.000000      39.000000      845.000000        6.000000
#
#             open_acc       pub_rec  ...      tax_liens  total_bal_ex_mort  \
# count  406075.000000  406075.00000  ...  406075.000000       4.060750e+05
# mean       12.161537       0.25068  ...       0.058381       5.166525e+04
# std         5.496255       0.64845  ...       0.428048       4.758017e+04
# min         1.000000       0.00000  ...       0.000000       0.000000e+00
# 25%         8.000000       0.00000  ...       0.000000       2.302800e+04
# 50%        11.000000       0.00000  ...       0.000000       3.942700e+04
# 75%        15.000000       0.00000  ...       0.000000       6.472050e+04
# max        90.000000      86.00000  ...      85.000000       2.688920e+06
#
#        home_ownership_MORTGAGE  home_ownership_OWN  \
# count            406075.000000       406075.000000
# mean                  0.511728            0.101698
# std                   0.499863            0.302251
# min                   0.000000            0.000000
# 25%                   0.000000            0.000000
# 50%                   1.000000            0.000000
# 75%                   1.000000            0.000000
# max                   1.000000            1.000000
#
#        verification_status_Source Verified  verification_status_Verified  \
# count                        406075.000000                 406075.000000
# mean                              0.415770                      0.294941
# std                               0.492855                      0.456017
# min                               0.000000                      0.000000
# 25%                               0.000000                      0.000000
# 50%                               0.000000                      0.000000
# 75%                               1.000000                      1.000000
# max                               1.000000                      1.000000
#
#         pymnt_plan_y  initial_list_status_w  application_type_Joint App  \
# count  406075.000000          406075.000000               406075.000000
# mean        0.000855               0.565698                    0.003522
# std         0.029220               0.495666                    0.059238
# min         0.000000               0.000000                    0.000000
# 25%         0.000000               0.000000                    0.000000
# 50%         0.000000               1.000000                    0.000000
# 75%         0.000000               1.000000                    0.000000
# max         1.000000               1.000000                    1.000000
#
#        debt_settlement_flag_Y
# count           406075.000000
# mean                 0.018819
# std                  0.135886
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                  1.000000
#
# [8 rows x 52 columns]

# %%
list(data6)
# Out:
# ['loan_amnt',
#  'int_rate',
#  'annual_inc',
#  'loan_status',
#  'dti',
#  'delinq_2yrs',
#  'fico_range_low',
#  'inq_last_6mths',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'out_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'last_pymnt_amnt',
#  'last_fico_range_high',
#  'policy_code',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'acc_open_past_24mths',
#  'bc_open_to_buy',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_inq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'total_bal_ex_mort',
#  'home_ownership_MORTGAGE',
#  'home_ownership_OWN',
#  'verification_status_Source Verified',
#  'verification_status_Verified',
#  'pymnt_plan_y',
#  'initial_list_status_w',
#  'application_type_Joint App',
#  'debt_settlement_flag_Y']

# %%
variables = pd.read_excel('LC_cleaned.xlsx').dropna()
variables.style.set_properties(subset=['Description'], **{'width' :'850px'})
# Out:
# <style  type="text/css" >
#     #T_ef655364_3625_11eb_a33f_acde48001122row0_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row1_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row2_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row3_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row4_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row5_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row6_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row7_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row8_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row9_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row10_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row11_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row12_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row13_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row14_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row15_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row16_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row17_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row18_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row19_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row20_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row21_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row22_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row23_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row24_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row25_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row26_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row27_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row28_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row29_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row30_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row31_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row32_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row33_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row34_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row35_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row36_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row37_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row38_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row39_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row40_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row41_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row42_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row43_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row44_col1 {
#             width:  850px;
#         }    #T_ef655364_3625_11eb_a33f_acde48001122row45_col1 {
#             width:  850px;
#         }</style><table id="T_ef655364_3625_11eb_a33f_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >LoanStatNew</th>        <th class="col_heading level0 col1" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef655364_3625_11eb_a33f_acde48001122level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row0_col0" class="data row0 col0" >acc_now_delinq</td>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row0_col1" class="data row0 col1" >The number of accounts on which the borrower is now delinquent.</td>
#             </tr>
#             <tr>
#                         <th id="T_ef655364_3625_11eb_a33f_acde48001122level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row1_col0" class="data row1 col0" >acc_open_past_24mths</td>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row1_col1" class="data row1 col1" >Number of trades opened in past 24 months.</td>
#             </tr>
#             <tr>
#                         <th id="T_ef655364_3625_11eb_a33f_acde48001122level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row2_col0" class="data row2 col0" >annual_inc</td>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row2_col1" class="data row2 col1" >The self-reported annual income provided by the borrower during registration.</td>
#             </tr>
#             <tr>
#                         <th id="T_ef655364_3625_11eb_a33f_acde48001122level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row3_col0" class="data row3 col0" >application_type</td>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row3_col1" class="data row3 col1" >Indicates whether the loan is an individual application or a joint application with two co-borrowers</td>
#             </tr>
#             <tr>
#                         <th id="T_ef655364_3625_11eb_a33f_acde48001122level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row4_col0" class="data row4 col0" >bc_open_to_buy</td>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row4_col1" class="data row4 col1" >.-</td>
#             </tr>
#             <tr>
#                         <th id="T_ef655364_3625_11eb_a33f_acde48001122level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row5_col0" class="data row5 col0" >chargeoff_within_12_mths</td>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row5_col1" class="data row5 col1" >Number of charge-offs within 12 months / Como multas por atrasarte / solo 118 que no son 0</td>
#             </tr>
#             <tr>
#                         <th id="T_ef655364_3625_11eb_a33f_acde48001122level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row6_col0" class="data row6 col0" >delinq_2yrs</td>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row6_col1" class="data row6 col1" >The number of 30+ days past-due incidences of delinquency in the borrower's credit file for the past 2 years</td>
#             </tr>
#             <tr>
#                         <th id="T_ef655364_3625_11eb_a33f_acde48001122level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ef655364_3625_11eb_a33f_acde48001122row7_col0" class="data row

# %%
data6.iloc[:,0:16].hist(bins=20, figsize=(25,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b564b880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b564e100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b1671550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b1690550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b16b1cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b16dc3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b16dc4c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b16fdca0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b187eb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b18b4310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b18dfa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b1913250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b193c9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b1972190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b199c910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b19c7130>]],
#       dtype=object)

# %%
data6.iloc[:,17:34].hist(bins=20, figsize=(25,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b6cb1670>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b6aeacd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b6d38160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b5b198e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b1735100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b1768760>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b1768850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b179d070>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b5b7fee0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7dab6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7dd6e20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7e0a5e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7e33d60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7e69520>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7e92ca0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7ec8490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7ef2c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7f29310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7f46c40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b7f7a400>]],
#       dtype=object)

# %%
data6.iloc[:,35:51].hist(bins=20, figsize=(25,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b60b9f70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b62523a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b627e430>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b62a0bb0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b62d4370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b62f9a30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b62f9b20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b632f340>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b638e1f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b63b7970>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b63ee130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b64168b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b64410d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b64757f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b64a0f70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb1b82c1730>]],
#       dtype=object)

# %%
data6.to_csv('loan_clean.csv')
